# %%
import neuprint
import networkx as nx
import pandas as pd
import physnet as pn
import numpy as np

# %%
phy_net = pn.PhysNet()

# %%
phy_net.read_swc('data/Coral.swc')

# %%
phy_net.df
# Out:
#       node_id  type     x      y      z    radius  parents
# 0           1     0  18.0  119.0  211.0  1.000000       -1
# 1           2     0  19.0  120.0  210.0  2.000000        1
# 2           3     0  20.0  120.0  210.0  2.828427        2
# 3           5     0  21.0  120.0  210.0  3.605551        3
# 4           7     0  22.0  120.0  210.0  4.242640        5
# ...       ...   ...   ...    ...    ...       ...      ...
# 7416       36     0  32.0  215.0   84.0  4.582576       32
# 7417       35     0  32.0  215.0   83.0  4.000000       36
# 7418       29     0  31.0  215.0   82.0  3.000000       35
# 7419       26     0  30.0  214.0   81.0  2.000000       29
# 7420       23     0  29.0  213.0   80.0  1.000000       26
#
# [7421 rows x 7 columns]

# %%
phy_net.create_g()

# %%
phy_net.degree_segment()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/networkx/classes/graph.py in bunch_iter(nlist, adj)
#    1907                 try:
# -> 1908                     for n in nlist:
#    1909                         if n in adj:
#
# TypeError: 'numpy.int64' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# NetworkXError                             Traceback (most recent call last)
# /var/folders/2g/f411k3y54zj8kddxt7xbcslr0000gp/T/ipykernel_32504/1920621370.py in <module>
# ----> 1 phy_net.degree_segment()
#
# ~/Documents/laszlo/physnet/physnet/segmentation/physnet.py in degree_segment(self, d)
#      66                         u = v
#      67                     else:
# ---> 68                         self.contracted_g = nx.contracted_nodes(self.contracted_g,u,v)
#      69
# ...

# %%
list(nx.dfs_edges(phy_net.g))
# Out:
# [(1, -1),
#  (1, 2),
#  (2, 3),
#  (3, 5),
#  (5, 7),
#  (7, 9),
#  (9, 11),
#  (11, 13),
#  (13, 15),
#  (15, 17),
#  (17, 19),
#  (19, 21),
#  (21, 24),
#  (24, 27),
#  (27, 30),
#  (30, 37),
#  (37, 40),
#  (40, 43),
#  (43, 47),
#  (47, 50),
#  (50, 53),
#  (53, 57),
#  (57, 60),
#  (60, 63),
#  (63, 66),
#  (66, 72),
#  (72, 75),
#  (75, 80),
#  (80, 83),
#  (83, 86),
#  (86, 89),
#  (89, 90),
#  (90, 93),
#  (93, 94),
#  (94, 95),
#  (95, 98),
#  (98, 99),
#  (99, 102),
#  (102, 103),
#  (103, 106),
#  (106, 107),
#  (107, 111),
#  (111, 112),
#  (112, 116),
#  (116, 120),
#  (120, 121),
#  (121, 128),
#  (128, 139),
#  (139, 146),
#  (146, 151),
#  (151, 152),
#  (152, 158),
#  (158, 163),
#  (163, 169),
#  (169, 174),
#  (174, 179),
#  (179, 184),
#  (184, 189),
#  (189, 194),
#  (194, 199),
#  (199, 204),
#  (204, 209),
#  (209, 214),
#  (214, 219),
#  (219, 224),
#  (224, 229),
#  (229, 234),
#  (234, 240),
#  (240, 247),
#  (247, 254),
#  (254, 262),
#  (262, 270),
# ...
