# %%
import physnet
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
test = physnet.PhysNet()

# %%
test.read_swc('test.swc')

# %%
test.create_g()

# %%
pos = {test.df.iloc[i,0]: test.df.iloc[i,[2,3,4]] for i in range(len(test.df))}

# %%
test.degree_segment()

# %%
test.draw_networkx()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2g/f411k3y54zj8kddxt7xbcslr0000gp/T/ipykernel_53638/2050015588.py in <module>
# ----> 1 test.draw_networkx()
#
# ~/Documents/laszlo/physnet/physnet/physnet.py in draw_networkx(self, cmap_name, file)
#      64
#      65         # Make plot
# ---> 66         nx.draw(self.g,pos=pos,edge_color=colors,node_size=.1)
#      67         if file:
#      68             plt.savefig(file)
#
# ~/anaconda3/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py in draw(G, pos, ax, **kwds)
#     119         kwds["with_labels"] = "labels" in kwds
#     120
# --> 121     draw_networkx(G, pos=pos, ax=ax, **kwds)
#     122     ax.set_axis_off()
#     123     plt.draw_if_interactive()
#
# ~/anaconda3/lib/python3.9/site-packages/networkx/drawing/nx_pylab.py in draw_networkx(G, pos, arrows, with_labels, **kwds)
#     302
# ...

# %%
nx.draw(test.g,node_size=2,pos=pos)
